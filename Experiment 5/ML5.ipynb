# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

# %%
data = pd.read_csv("iris.csv")
features = np.unique(data.species)
x = data.drop(columns=['species'])
y = data['species']
print(x)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

gnb.fit(x_train, y_train)
y_pred_gnb = gnb.predict(x_test)
accuracy = accuracy_score(y_test, y_pred_gnb)
print(f"Accuracy of Gaussian NB: {accuracy * 100:.2f}%")

mnb.fit(x_train, y_train)
y_pred_mnb = mnb.predict(x_test)
accuracy = accuracy_score(y_test, y_pred_mnb)
print(f"Accuracy of Multinomial NB: {accuracy * 100:.2f}%")

bnb.fit(x_train, y_train)
y_pred_bnb = gnb.predict(x_test)
accuracy = accuracy_score(y_test, y_pred_bnb)
print(f"Accuracy of Bernoulli NB: {accuracy * 100:.2f}%")
# Out:
# Accuracy of Gaussian NB: 100.00%
# Accuracy of Multinomial NB: 90.00%
# Accuracy of Bernoulli NB: 100.00%

# %%
cm = confusion_matrix(y_test, y_pred_gnb)
sns.heatmap(cm, annot=True, cmap='Purples', xticklabels=features, yticklabels=features)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion Matrix of Gaussian NB')
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_mnb)
sns.heatmap(cm, annot=True, cmap='Purples', xticklabels=features, yticklabels=features)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion Matrix of Multinomial NB')
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_bnb)
sns.heatmap(cm, annot=True, cmap='Purples', xticklabels=features, yticklabels=features)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion Matrix of Bernoulli NB')
plt.show()
